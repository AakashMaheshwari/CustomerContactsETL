# %%
import pandas as pd
import json
json_file_path = "C:\\Users\\avsma\\Downloads\\Data Engineering - End to End Projects\\Practice Projects\\Project 1 - Customer Contacts ETL\\CustomerContactsETL\\RawData\\Customer_Contacts_RawData.json"

# %%
#printing the entire json and individual columns
df = pd.read_json(json_file_path)
#print(df.to_string())
print(df['email'])
# Out:
# 0           katherine60@hotmail.com
# 1              kboyer@reichert.info
# 2                dbrown@hotmail.com
# 3            joanie.toy@hackett.com
# 4             wendy.zieme@yahoo.com
#                    ...
# 6108        rogahn.vickie@yahoo.com
# 6109    vicente.keebler@hackett.com
# 6110           fern54@gutkowski.org
# 6111             wava.lind@wolf.com
# 6112            emmalee69@yahoo.com
# Name: email, Length: 6113, dtype: object
