# %%
import pyodbc
#conn=pyodbc.connect('Driver={SQL Server}; Server=DESKTOP-VAB29GJ; DATABASE=CustomerContactsETL; Trusted_connection=yes')
cursor=conn.cursor()

# %%
import sys
import os
sys.path.append('C:\\Users\\avsma\\Downloads\\Data Engineering - End to End Projects\\Practice Projects\\Project 1 - Customer Contacts ETL\\CustomerContactsETL')

# %%
from ipynb.fs.full.main import FirstName, LastName, AddressLine1, AddressLine2, State, Pincode, Contacts_Phone, EmailList, WebsiteList
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from ipynb.fs.full.main import FirstName, LastName, AddressLine1, AddressLine2, State, Pincode, Contacts_Phone, EmailList, WebsiteList
#
# File ~\Downloads\Data Engineering - End to End Projects\Practice Projects\Project 1 - Customer Contacts ETL\CustomerContactsETL\main.ipynb:23
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "code",
#       5    "execution_count": 1,
#       6    "metadata": {},
#       7    "outputs": [],
#       8    "source": [
#       9     "#!pip install ipynb"
#      10    ]
#      11   },
#      12   {
#      13    "cell_type": "code",
#      14    "execution_count": 1,
#      15    "metadata": {},
#      16    "outputs": [],
#      17    "source": [
#      18     "from ipynb.fs.full.ETL_Pipeline.extract import extract_data\n",
# ...

# %%
insert_query = """
INSERT INTO customer_contact (FirstName, LastName, AddressLine1, AddressLine2, State, Pincode, Phone,Email,Website)
VALUES (?,?,?,?,?,?,?,?,?);
 """

# %%
customer_data=list(zip(FirstName,
    LastName,
    AddressLine1,
    AddressLine2,
    State,
    Pincode,
    Contacts_Phone,
    EmailList,
    WebsiteList))
print(customer_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 customer_data=list(zip(FirstName,
#       2     LastName,
#       3     AddressLine1,
#       4     AddressLine2,
#       5     State,
#       6     Pincode,
#       7     Contacts_Phone,
#       8     EmailList,
#       9     WebsiteList))
#      10 print(customer_data)
#
# NameError: name 'FirstName' is not defined

# %%
cursor.executemany(insert_query,customer_data)

conn.commit()

cursor.close()
conn.close()
